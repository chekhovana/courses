# %% [markdown]
# # Пример использования библиотеки gensim для тематического моделирования

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/stepik/m3. unsupervised/w4. topic modeling/4.3 gensim demo/data'
# !ls
# Out:
# /content/drive/MyDrive/Colab Notebooks/stepik/m3. unsupervised/w4. topic modeling/4.3 gensim demo/data
# docword.xkcd.txt  vocab.xkcd.txt

# %%
from gensim import corpora, models

# %%
# Импортируем данные в формте UCI Bag of Words
data = corpora.UciCorpus("docword.xkcd.txt", "vocab.xkcd.txt")
dictionary = data.create_dictionary()

# %%
print(len(data))
# for d in data:
#     print(d)
# Out:
# 1265

# %%
# обучение модель
# %time ldamodel = models.ldamodel.LdaModel(data, id2word=dictionary, num_topics=5, passes=20, alpha=1.25, eta=1.25)
# Out:
# CPU times: user 30.2 s, sys: 448 ms, total: 30.6 s
# Wall time: 30.4 s

# %%
# Сохранение модели
ldamodel.save("ldamodel_xkcd")

# %%
# Загрузка модели
ldamodel = models.ldamodel.LdaModel.load("ldamodel_xkcd")

# %%
# выводим топы слов
for t, top_words in ldamodel.print_topics(num_topics=10, num_words=10):
    print("Topic", t, ":", top_words)
# Out:
# Topic 0 : 0.003*"b'exhibit'" + 0.002*"b'paul'" + 0.002*"b'ron'" + 0.001*"b'degree'" + 0.001*"b'mark'" + 0.001*"b'base'" + 0.001*"b'center'" + 0.001*"b'line'" + 0.001*"b'label'" + 0.001*"b'centigrade'"
# Topic 1 : 0.002*"b'person'" + 0.002*"b'labeled'" + 0.001*"b'island'" + 0.001*"b'wave'" + 0.001*"b'text'" + 0.001*"b'page'" + 0.001*"b'title'" + 0.001*"b'error'" + 0.001*"b'ago'" + 0.001*"b'list'"
# Topic 2 : 0.003*"b'line'" + 0.003*"b'graph'" + 0.003*"b'text'" + 0.002*"b'one'" + 0.002*"b'number'" + 0.002*"b'title'" + 0.002*"b'day'" + 0.001*"b'time'" + 0.001*"b'within'" + 0.001*"b'goggles'"
# Topic 3 : 0.002*"b'wait'" + 0.002*"b'sagal'" + 0.002*"b'peter'" + 0.002*"b'nathan'" + 0.001*"b'gliese'" + 0.001*"b'bag'" + 0.001*"b'dont'" + 0.001*"b'spirit'" + 0.001*"b'planet'" + 0.001*"b'destroy'"
# Topic 4 : 0.024*"b'man'" + 0.012*"b'text'" + 0.012*"b'person'" + 0.010*"b'title'" + 0.010*"b'woman'" + 0.009*"b'guy'" + 0.006*"b'one'" + 0.006*"b'girl'" + 0.005*"b'just'" + 0.005*"b'hat'"

# %%
# Вычисляем логарифм перплексии и немного преобразуем, чтобы привести к общепринятому виду
# perplexity = ldamodel.log_perplexity(list(data))
# print(2**(-perplexity))
ldamodel.log_perplexity(list(data))
# Out:
# -8.456802548406587

# %%
perp = ldamodel.bound(data)
2**(-perp/float(87409))
# Out:
# 351.35912458782343

# %%
# Добавление в модель новых документов, содержащихся в новом корупсе data2
# ldamodel.update(data2, passes=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-a67d52d954fd> in <module>()
#       1 # Добавление в модель новых документов, содержащихся в новом корупсе data2
# ----> 2 ldamodel.update(data2, passes=10)
#
# NameError: name 'data2' is not defined

# %%
# Получение распределения тем для конкретного документа
doc = list(data)[0]
ldamodel.get_document_topics(doc)
