# %% [markdown]
# # Выбор семейства распределений в наивном байесе

# %% [markdown]
# Вам предлагается выяснить, какое распределение лучше использовать в наивном байесовском классификаторе в зависимости от вида признаков.

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.naive_bayes import BernoulliNB, MultinomialNB, GaussianNB
from sklearn.datasets import load_digits, load_breast_cancer
from sklearn.model_selection import cross_val_score

# %% [markdown]
# Загрузите датасеты digits и breast_cancer из sklearn.datasets. Выведите несколько строчек из обучающих выборок и посмотрите на признаки.

# %%
digits_x, digits_y = load_digits(return_X_y=True)
cancer_x, cancer_y = load_breast_cancer(return_X_y=True)

# %% [markdown]
# С помощью sklearn.cross_validation.cross_val_score c настройками по умолчанию и вызова метода mean() у возвращаемого этой функцией numpy.ndarray, сравните качество работы наивных байесовских классификаторов на этих двух датасетах. Для сравнения предлагается использовать BernoulliNB, MultinomialNB и GaussianNB. Насколько полученные результаты согласуются с рекомендациями из лекций?

# %%
bernoulli = BernoulliNB()
multinomial = MultinomialNB()
gaussian = GaussianNB()

# %%
print('digits bernoulli', cross_val_score(bernoulli, digits_x, digits_y).mean())
print('digits multinomial', cross_val_score(multinomial, digits_x, digits_y).mean())
print('digits gaussian', cross_val_score(gaussian, digits_x, digits_y).mean())
# Out:
# digits bernoulli 0.8258236507780582
# digits multinomial 0.8708771489735053
# digits gaussian 0.8186003803550138

# %%
print('cancer bernoulli', cross_val_score(bernoulli, cancer_x, cancer_y).mean())
print('cancer multinomial', cross_val_score(multinomial, cancer_x, cancer_y).mean())
print('cancer gaussian', cross_val_score(gaussian, cancer_x, cancer_y).mean())
# Out:
# cancer bernoulli 0.6274204028589994
# cancer multinomial 0.8945790401930752
# cancer gaussian 0.9367492806089297

# %% [markdown]
# Выводы:
#
# На выборке с целочисленными неотрицательными признаками лучше всего сработало мультиномиальное распределение.
#
# На вещественных признаках лучше всего сработало нормальное распределение.
