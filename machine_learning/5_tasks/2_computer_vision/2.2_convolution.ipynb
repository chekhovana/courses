# %% [markdown]
# https://github.com/ianormy/ConvolutionFilters/blob/master/ConvolutionFilters.ipynb

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/courses/stepik/m5. tasks/w2. computer vision'
# !ls
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/courses/stepik/m5. tasks/w2. computer vision'
# /content
# sample_data

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = cv2.cvtColor(cv2.imread('opencv-logo.png'), cv2.COLOR_BGR2GRAY)
kernel = np.array(([0, 1, 0], 
                      [1, -4, 1], 
                      [0, 1, 0]), dtype="int")
dst = cv2.filter2D(img, -1, kernel)
plt.subplot(121)
plt.imshow(img, cmap='gray')
plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122)
plt.imshow(dst, cmap='gray'),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-344a575843a4> in <module>()
#       2 import cv2
#       3 from matplotlib import pyplot as plt
# ----> 4 img = cv2.cvtColor(cv2.imread('opencv-logo.png'), cv2.COLOR_BGR2GRAY)
#       5 kernel = np.array(([0, 1, 0],
#       6                       [1, -4, 1],
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
from skimage.data import astronaut      # pip install scikit-image

# %%
def show_gray_image(im):
    frame = plt.gca()
    frame.axes.get_xaxis().set_visible(False)
    frame.axes.get_yaxis().set_visible(False)
    plt.imshow(im, cmap='gray')

# %%
image = astronaut()
print(image.shape)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # convert the color image to gray
print(gray.shape)
show_gray_image(gray)
# Out:
# (512, 512, 3)
# (512, 512)

# %%
laplacian = np.array(([0, 1, 0], 
                      [1, -4, 1], 
                      [0, 1, 0]), dtype="int")
laplacian_img = cv2.filter2D(gray, -1, laplacian)
show_gray_image(laplacian_img)

# %%
kernel = np.array(([1, 0, -1], 
                      [1, 0, -1], 
                      [1, 0, -1]), dtype="int")
laplacian_img = cv2.filter2D(gray, -1, kernel)
print(gray.dtype)
# show_gray_image(laplacian_img)
# Out:
# uint8

# %%
np.random.seed(0)
# img = np.random.randint(0, 256, size=(50, 50))
kernel = np.array(([0, 0, 0], [1, 0, 0], [0, 0, 0]), dtype="int")
transformed = cv2.filter2D(gray, -1, kernel)
print(gray[0])
print(transformed[0])

# %%
def display_images(img1, img2):
    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.imshow(img1, cmap='gray')
    plt.xticks([]), plt.yticks([])
    plt.subplot(122)
    plt.imshow(img2, cmap='gray')
    plt.xticks([]), plt.yticks([])
    plt.show()


img = cv2.cvtColor(astronaut(), cv2.COLOR_BGR2GRAY)
kernel = np.array(([1, 0, -1], [1, 0, -1], [1, 0, -1]), dtype="int")

transformed = cv2.filter2D(img, -1, kernel)
display_images(img, transformed)

# %%
img[0]
# Out:
# array([149, 110,  72,  65,  85, 101, 122, 135, 141, 134, 115,  92,  62,
#         23,  10,   4,   3,   2,   4,   8,  14,  19,  23,  21,  20,  23,
#         21,  19,  18,  20,  25,  43,  50,  60,  60,  40,  19,  14,  14,
#         38,  74, 105, 127, 142, 148, 152, 151, 155, 155, 157, 161, 156,
#        158, 158, 160, 158, 160, 163, 162, 161, 160, 160, 158, 160, 162,
#        158, 162, 159, 163, 165, 163, 165, 168, 167, 166, 166, 168, 169,
#        167, 167, 169, 171, 168, 169, 172, 174, 169, 172, 171, 171, 172,
#        175, 170, 171, 173, 175, 170, 172, 172, 172, 175, 175, 173, 179,
#        175, 175, 177, 181, 177, 174, 174, 172, 175, 173, 171, 167, 166,
#        164, 165, 167, 164, 162, 164, 163, 165, 164, 162, 165, 161, 162,
#        163, 166, 166, 165, 167, 165, 168, 167, 167, 171, 173, 175, 176,
#        179, 181, 180, 182, 181, 183, 187, 181, 185, 184, 180, 186, 186,
#        190, 184, 185, 185, 183, 185, 182, 185, 184, 181, 182, 182, 181,
# ...

# %%
import numpy as np
import cv2
x = np.uint8([240])
y = np.uint8([10])
# print(cv2.add(x, y))
x, y, x + y
# Out:
# (array([240], dtype=uint8),
#  array([10], dtype=uint8),
#  array([250], dtype=uint8))
